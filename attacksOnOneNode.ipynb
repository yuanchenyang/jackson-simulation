# %%
import numpy as np
import scipy.linalg as la
import scipy.stats as sps
import networkx as nx
from matplotlib import pyplot as plt
from simulation import *
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# create a dense network with 5 nodes
# same customer arrival rate 1.1 at each node,
# and same travel time of 1, and initialized with 100 cars 
# at each station, and add attacks on node 0.
# in this scenario of attacks, 
from collections import Counter

test_nw = node_attack(5, 1.1, 10., 100, .5)

times, states = simulate(test_nw, 50000)
for y in zip(*states):
    plt.plot(times, y)
    
print map(np.mean, zip(*states))
# Out:
# [3.5385599999999999, 273.44114000000002, 66.237260000000006, 75.002660000000006, 80.753100000000003]

# %%
from collections import Counter

test_nw = full_network(5, 1.1, 10., 100)

times, states = simulate(test_nw, 50000)
for y in zip(*states):
    plt.plot(times, y)
    
print map(np.mean, zip(*states))
# Out:
# [103.80586, 67.104600000000005, 155.81688, 89.946399999999997, 82.272319999999993]
