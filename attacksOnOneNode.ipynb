# %%
import numpy as np
import scipy.linalg as la
import scipy.stats as sps
import networkx as nx
from matplotlib import pyplot as plt
from simulation import *
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# create a dense network with 3 nodes
# same customer arrival rate 1.1 at each node,
# and same travel time of 1, and initialized with 100 cars 
# at each station, and add attacks on node 0.
from collections import Counter

test_nw = node_attack(5, 1.1, 10., 100, .5)

times, states = simulate(test_nw, 10000)
for y in zip(*states):
    plt.plot(times, y)
    
print map(np.mean, zip(*states))
# Out:
# [14.562099999999999, 123.0493, 153.8254, 132.5095, 75.022000000000006]

# %%
# Out:
# [(0, 10), (1, 10), (2, 10), ('0->2', 0), ('0->1', 0), ('2->1', 0), ('1->0', 0), ('2->0', 0), ('1->2', 0)]
# [(0, 9), (1, 10), (2, 10), ('0->2', 1), ('0->1', 0), ('2->1', 0), ('1->0', 0), ('2->0', 0), ('1->2', 0)]
# [(0, 9), (1, 10), (2, 9), ('0->2', 1), ('0->1', 0), ('2->1', 1), ('1->0', 0), ('2->0', 0), ('1->2', 0)]
# [(0, 9), (1, 11), (2, 9), ('0->2', 1), ('0->1', 0), ('2->1', 0), ('1->0', 0), ('2->0', 0), ('1->2', 0)]
# [(0, 9), (1, 11), (2, 10), ('0->2', 0), ('0->1', 0), ('2->1', 0), ('1->0', 0), ('2->0', 0), ('1->2', 0)]

# %%
# Out:
# [22.733499999999999, 138.5752, 77.363100000000003, 139.0547, 121.22029999999999]

# %%
from collections import Counter

test_nw = full_network(5, 1.1, 10., 100)

times, states = simulate(test_nw, 10000)
for y in zip(*states):
    plt.plot(times, y)
    
print map(np.mean, zip(*states))
# Out:
# [123.111, 90.7958, 106.9837, 118.3571, 59.704599999999999]
